# %% [markdown]
# # 04 - Strategy Backtesting and Monte Carlo Risk Analysis
# Benchmark Alpha Hunter against Random Baseline, Pure Momentum, and SOL Buy-and-Hold.

# %%
from scripts.run_backtest import main as run_backtest_main

run_backtest_main()
