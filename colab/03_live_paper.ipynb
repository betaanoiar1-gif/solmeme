# %% [markdown]
# # 03 - Live Paper Trading Simulation ($100 USD Virtual Capital)
# Simulates automated paper buying, price walk monitoring, dynamic exits, and PnL accounting.

# %%
from scripts.run_live_paper import run_live_paper

# Run 6 live paper trading cycles
orchestrator = run_live_paper(cycles=6, interval=0.5)
