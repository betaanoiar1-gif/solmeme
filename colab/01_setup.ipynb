# %% [markdown]
# # 01 - Setup and Environment Verification for Meme Alpha Hunter
# This notebook verifies the environment, dependencies, database schema, and public RPC connections.

# %%
# Clone repo or install in Colab
# !git clone https://github.com/betaanoiar1-gif/solmeme.git || true
# %cd solmeme
# !pip install -r requirements.txt

# %%
from app.config.settings import load_config
from app.core.database import DatabaseManager
from app.core.health_monitor import HealthMonitor

config = load_config()
db = DatabaseManager(config.db_path)
health = HealthMonitor(db)
print('System Health Status:', health.get_system_summary())
